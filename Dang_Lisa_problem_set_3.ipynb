# %% [markdown]
# ## Our libraries that we are importing:

# %%
# 1. Importing all the libraries necessary for this assignment
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# For this task, we will be downloading data from a website, cleaning up the dataframe, and then storing it as an excel file.
#
# To clean up the dataframe we will do the following by web scrap:
# *   Make the index the different characters instead of 0, 1, 2, 3. It should be Godzilla, MUTO, King Kong...
# *   Change the column names to just be the names of the movies (e.g., it should just be Godzilla instead of Films, Godzilla, Monsters. Also, change the index name to also just be “character” instead of Character, Character, Monster
# *   Remove the row that has all duplicates (i.e., “human”, “human”, “human”), since that doesn’t seem helpful to us in this dataframe
# *   Save the file as a .csv with the delimiter being tabs

# %% [markdown]
# ### Web scraping the data:

# %% [markdown]
# Let's go ahead and web scrap our data from the Wikipedia page 'MonsterVerse'. We're going to be using the table 'Cast and characters'.

# %%
# 2. Load the data from the third table, 'Cast and characters', from the Wikipedia page
print('-------------------------------- 2 --------------------------------')
wiki_url = "https://en.wikipedia.org/wiki/MonsterVerse"
df = pd.read_html(wiki_url, header=0)[3]

df
# Out:
# -------------------------------- 2 --------------------------------
#               Character  ...                      Films.3
# 0             Character  ...            Godzilla vs. Kong
# 1              Monsters  ...                     Monsters
# 2              Godzilla  ...                          CGI
# 3                  MUTO  ...              Archive footage
# 4             King Kong  ...              Eric PeteyS[57]
# 5         King Ghidorah  ...              Archive footage
# 6                 Rodan  ...              Archive footage
# 7                Humans  ...                       Humans
# 8       Ishiro Serizawa  ...                          NaN
# 9       Vivienne Graham  ...                          NaN
# 10       William Stentz  ...                          NaN
# 11           Ford Brody  ...                          NaN
# 12           Elle Brody  ...                          NaN
# 13            Joe Brody  ...                          NaN
# 14         Sandra Brody  ...                          NaN
# 15       Houston Brooks  ...                          NaN
# 16        William Randa  ...  Pictured with archive audio
# 17         James Conrad  ...                          NaN
# 18          Hank Marlow  ...                          NaN
# 19         Mason Weaver  ...                          NaN
# 20      Preston Packard  ...                          NaN
# 21              San Lin  ...                          NaN
# 22         Mark Russell  ...                Kyle Chandler
# 23      Madison Russell  ...           Millie Bobby Brown
# 24         Emma Russell  ...                     Pictured
# 25  Ilene and Ling Chen  ...                          NaN
# 26         Rick Stanton  ...                          NaN
# 27          Sam Coleman  ...                          NaN
# 28           Alan Jonah  ...                          NaN
# 29         Diane Foster  ...                          NaN
# 30       Jackson Barnes  ...                          NaN
# 31          Nathan Lind  ...          Alexander Skarsgård
# 32        Ilene Andrews  ...                 Rebecca Hall
# 33                  Jia  ...                Kaylee Hottle
# 34         Bernie Hayes  ...            Brian Tyree Henry
# 35       Josh Valentine  ...              Julian Dennison
# 36       Walter Simmons  ...                Demián Bichir
# 37         Ren Serizawa  ...                   Shun Oguri
# 38         Maia Simmons  ...                Eiza González
# 39           Guillermin  ...                Lance Reddick
#
# [40 rows x 5 columns]

# %% [markdown]
# Alright! Now that we have retrieved the data table, we're going to clean up the data so that the table is easier to understand.

# %% [markdown]
# ### Cleaning up the data:

# %% [markdown]
# First, let's make the index be the column for the different chracters instead of 0, 1, 2, 3, and etc.

# %%
# 3. Replace the numeric index column with the characters column
print('-------------------------------- 3 --------------------------------')
data = df.set_index('Character')

data
# Out:
# -------------------------------- 3 --------------------------------
#                                              Films  ...                      Films.3
# Character                                           ...
# Character                                 Godzilla  ...            Godzilla vs. Kong
# Monsters                                  Monsters  ...                     Monsters
# Godzilla                               T.J. StormS  ...                          CGI
# MUTO                          Matt CrossSLee RossS  ...              Archive footage
# King Kong                                      NaN  ...              Eric PeteyS[57]
# King Ghidorah                                  NaN  ...              Archive footage
# Rodan                                          NaN  ...              Archive footage
# Humans                                      Humans  ...                       Humans
# Ishiro Serizawa                       Ken Watanabe  ...                          NaN
# Vivienne Graham                      Sally Hawkins  ...                          NaN
# William Stentz                    David Strathairn  ...                          NaN
# Ford Brody           Aaron Taylor-JohnsonCJ AdamsY  ...                          NaN
# Elle Brody                         Elizabeth Olsen  ...                          NaN
# Joe Brody                           Bryan Cranston  ...                          NaN
# Sandra Brody                      Juliette Binoche  ...                          NaN
# Houston Brooks                                 NaN  ...                          NaN
# William Randa                                  NaN  ...  Pictured with archive audio
# James Conrad                                   NaN  ...                          NaN
# Hank Marlow                                    NaN  ...                          NaN
# Mason Weaver                                   NaN  ...                          NaN
# Preston Packard                                NaN  ...                          NaN
# San Lin                                        NaN  ...                          NaN
# Mark Russell                                   NaN  ...                Kyle Chandler
# Madison Russell                                NaN  ...           Millie Bobby Brown
# Emma Russell                                   NaN  ...                     Pictured
# Ilene and Ling Chen                            NaN  ...                          NaN
# Rick Stanton                                   NaN  ...                          NaN
# Sam Coleman                                    NaN  ...                          NaN
# Alan Jonah                                     NaN  ...                          NaN
# Diane Foster                                   NaN  ...                          NaN
# Jackson Barnes                                 NaN  ...                          NaN
# Nathan Lind                                    NaN  ...          Alexander Skarsgård
# Ilene Andrews                                  NaN  ...                 Rebecca Hall
# Jia                                            NaN  ...                Kaylee Hottle
# Bernie Hayes                                   NaN  ...            Brian Tyree Henry
# Josh Valentine                                 NaN  ...              Julian Dennison
# Walter Simmons                                 NaN  ...                Demián Bichir
# Ren Serizawa                                   NaN  ...                   Shun Oguri
# Maia Simmons                                   NaN  ...                Eiza González
# Guillermin                                     NaN  ...                Lance Reddick
#
# [40 rows x 4 columns]

# %% [markdown]
# Next, we're going to change the column names to be just the names of the movies.

# %%
# 4a. Change the 'Films' name columns into the actual movie names
print('-------------------------------- 4a -------------------------------')
data.rename(columns={'Films':'Godzilla'}, inplace=True)
data.rename(columns={'Films.1':'Kong:Skull Island'}, inplace=True)
data.rename(columns={'Films.2':'Godzilla:King of the Monsters'}, inplace=True)
data.rename(columns={'Films.3':'Godzilla vs. Kong'}, inplace=True)

data
# Out:
# -------------------------------- 4a -------------------------------
#                                           Godzilla  ...            Godzilla vs. Kong
# Character                                           ...
# Character                                 Godzilla  ...            Godzilla vs. Kong
# Monsters                                  Monsters  ...                     Monsters
# Godzilla                               T.J. StormS  ...                          CGI
# MUTO                          Matt CrossSLee RossS  ...              Archive footage
# King Kong                                      NaN  ...              Eric PeteyS[57]
# King Ghidorah                                  NaN  ...              Archive footage
# Rodan                                          NaN  ...              Archive footage
# Humans                                      Humans  ...                       Humans
# Ishiro Serizawa                       Ken Watanabe  ...                          NaN
# Vivienne Graham                      Sally Hawkins  ...                          NaN
# William Stentz                    David Strathairn  ...                          NaN
# Ford Brody           Aaron Taylor-JohnsonCJ AdamsY  ...                          NaN
# Elle Brody                         Elizabeth Olsen  ...                          NaN
# Joe Brody                           Bryan Cranston  ...                          NaN
# Sandra Brody                      Juliette Binoche  ...                          NaN
# Houston Brooks                                 NaN  ...                          NaN
# William Randa                                  NaN  ...  Pictured with archive audio
# James Conrad                                   NaN  ...                          NaN
# Hank Marlow                                    NaN  ...                          NaN
# Mason Weaver                                   NaN  ...                          NaN
# Preston Packard                                NaN  ...                          NaN
# San Lin                                        NaN  ...                          NaN
# Mark Russell                                   NaN  ...                Kyle Chandler
# Madison Russell                                NaN  ...           Millie Bobby Brown
# Emma Russell                                   NaN  ...                     Pictured
# Ilene and Ling Chen                            NaN  ...                          NaN
# Rick Stanton                                   NaN  ...                          NaN
# Sam Coleman                                    NaN  ...                          NaN
# Alan Jonah                                     NaN  ...                          NaN
# Diane Foster                                   NaN  ...                          NaN
# Jackson Barnes                                 NaN  ...                          NaN
# Nathan Lind                                    NaN  ...          Alexander Skarsgård
# Ilene Andrews                                  NaN  ...                 Rebecca Hall
# Jia                                            NaN  ...                Kaylee Hottle
# Bernie Hayes                                   NaN  ...            Brian Tyree Henry
# Josh Valentine                                 NaN  ...              Julian Dennison
# Walter Simmons                                 NaN  ...                Demián Bichir
# Ren Serizawa                                   NaN  ...                   Shun Oguri
# Maia Simmons                                   NaN  ...                Eiza González
# Guillermin                                     NaN  ...                Lance Reddick
#
# [40 rows x 4 columns]

# %% [markdown]
# Let's change the index name to be lowercase.

# %%
# 4b. Change the index name to start with lowercase instead of uppercase
print('-------------------------------- 4b -------------------------------')
data.index.name = "character"

data
# Out:
# -------------------------------- 4b -------------------------------
#                                           Godzilla  ...            Godzilla vs. Kong
# character                                           ...
# Character                                 Godzilla  ...            Godzilla vs. Kong
# Monsters                                  Monsters  ...                     Monsters
# Godzilla                               T.J. StormS  ...                          CGI
# MUTO                          Matt CrossSLee RossS  ...              Archive footage
# King Kong                                      NaN  ...              Eric PeteyS[57]
# King Ghidorah                                  NaN  ...              Archive footage
# Rodan                                          NaN  ...              Archive footage
# Humans                                      Humans  ...                       Humans
# Ishiro Serizawa                       Ken Watanabe  ...                          NaN
# Vivienne Graham                      Sally Hawkins  ...                          NaN
# William Stentz                    David Strathairn  ...                          NaN
# Ford Brody           Aaron Taylor-JohnsonCJ AdamsY  ...                          NaN
# Elle Brody                         Elizabeth Olsen  ...                          NaN
# Joe Brody                           Bryan Cranston  ...                          NaN
# Sandra Brody                      Juliette Binoche  ...                          NaN
# Houston Brooks                                 NaN  ...                          NaN
# William Randa                                  NaN  ...  Pictured with archive audio
# James Conrad                                   NaN  ...                          NaN
# Hank Marlow                                    NaN  ...                          NaN
# Mason Weaver                                   NaN  ...                          NaN
# Preston Packard                                NaN  ...                          NaN
# San Lin                                        NaN  ...                          NaN
# Mark Russell                                   NaN  ...                Kyle Chandler
# Madison Russell                                NaN  ...           Millie Bobby Brown
# Emma Russell                                   NaN  ...                     Pictured
# Ilene and Ling Chen                            NaN  ...                          NaN
# Rick Stanton                                   NaN  ...                          NaN
# Sam Coleman                                    NaN  ...                          NaN
# Alan Jonah                                     NaN  ...                          NaN
# Diane Foster                                   NaN  ...                          NaN
# Jackson Barnes                                 NaN  ...                          NaN
# Nathan Lind                                    NaN  ...          Alexander Skarsgård
# Ilene Andrews                                  NaN  ...                 Rebecca Hall
# Jia                                            NaN  ...                Kaylee Hottle
# Bernie Hayes                                   NaN  ...            Brian Tyree Henry
# Josh Valentine                                 NaN  ...              Julian Dennison
# Walter Simmons                                 NaN  ...                Demián Bichir
# Ren Serizawa                                   NaN  ...                   Shun Oguri
# Maia Simmons                                   NaN  ...                Eiza González
# Guillermin                                     NaN  ...                Lance Reddick
#
# [40 rows x 4 columns]

# %% [markdown]
# Since there are redundant rows for the data being shown, we'll remove those rows so there's no more duplicates. We'll also remove the first row since it is an exact duplicate of the column and index titles.

# %%
# 5. Remove the rows that have  duplicates
print('-------------------------------- 5 --------------------------------')
data.drop(['Character', 'Monsters', 'Humans'], axis=0, inplace=True)

data
# Out:
# -------------------------------- 5 --------------------------------
#                                           Godzilla  ...            Godzilla vs. Kong
# character                                           ...
# Godzilla                               T.J. StormS  ...                          CGI
# MUTO                          Matt CrossSLee RossS  ...              Archive footage
# King Kong                                      NaN  ...              Eric PeteyS[57]
# King Ghidorah                                  NaN  ...              Archive footage
# Rodan                                          NaN  ...              Archive footage
# Ishiro Serizawa                       Ken Watanabe  ...                          NaN
# Vivienne Graham                      Sally Hawkins  ...                          NaN
# William Stentz                    David Strathairn  ...                          NaN
# Ford Brody           Aaron Taylor-JohnsonCJ AdamsY  ...                          NaN
# Elle Brody                         Elizabeth Olsen  ...                          NaN
# Joe Brody                           Bryan Cranston  ...                          NaN
# Sandra Brody                      Juliette Binoche  ...                          NaN
# Houston Brooks                                 NaN  ...                          NaN
# William Randa                                  NaN  ...  Pictured with archive audio
# James Conrad                                   NaN  ...                          NaN
# Hank Marlow                                    NaN  ...                          NaN
# Mason Weaver                                   NaN  ...                          NaN
# Preston Packard                                NaN  ...                          NaN
# San Lin                                        NaN  ...                          NaN
# Mark Russell                                   NaN  ...                Kyle Chandler
# Madison Russell                                NaN  ...           Millie Bobby Brown
# Emma Russell                                   NaN  ...                     Pictured
# Ilene and Ling Chen                            NaN  ...                          NaN
# Rick Stanton                                   NaN  ...                          NaN
# Sam Coleman                                    NaN  ...                          NaN
# Alan Jonah                                     NaN  ...                          NaN
# Diane Foster                                   NaN  ...                          NaN
# Jackson Barnes                                 NaN  ...                          NaN
# Nathan Lind                                    NaN  ...          Alexander Skarsgård
# Ilene Andrews                                  NaN  ...                 Rebecca Hall
# Jia                                            NaN  ...                Kaylee Hottle
# Bernie Hayes                                   NaN  ...            Brian Tyree Henry
# Josh Valentine                                 NaN  ...              Julian Dennison
# Walter Simmons                                 NaN  ...                Demián Bichir
# Ren Serizawa                                   NaN  ...                   Shun Oguri
# Maia Simmons                                   NaN  ...                Eiza González
# Guillermin                                     NaN  ...                Lance Reddick
#
# [37 rows x 4 columns]

# %% [markdown]
# We've removed the data that will be unhelpful or unnecessary. Now the table is clearer to read and understand.

# %% [markdown]
# ### Saving the new data as a file:

# %% [markdown]
# We are going to save our new data as a .csv file with the delimiter being tabs.

# %%
# 6. Saving as a .csv file
print('-------------------------------- 6 -------------------------------')
data.to_csv('MonsterVerse.csv', sep ='\t')

new_data = pd.read_csv('MonsterVerse.csv')
new_data
# Out:
# -------------------------------- 6 -------------------------------
#    character\tGodzilla\tKong:Skull Island\tGodzilla:King of the Monsters\tGodzilla vs. Kong
# 0   Godzilla\tT.J. StormS\tPictured with archive a...
# 1   MUTO\tMatt CrossSLee RossS\t\tCGI\tArchive foo...
# 2   King Kong\t\tTerry NotarySToby KebbellS\tArchi...
# 3   King Ghidorah\t\tPictured\tJason LilesSAlan Ma...
# 4    Rodan\t\tPictured\tJason LilesS\tArchive footage
# 5     Ishiro Serizawa\tKen Watanabe\t\tKen Watanabe\t
# 6   Vivienne Graham\tSally Hawkins\t\tSally Hawkins\t
# 7   William Stentz\tDavid Strathairn\t\tDavid Stra...
# 8     Ford Brody\tAaron Taylor-JohnsonCJ AdamsY\t\t\t
# 9                   Elle Brody\tElizabeth Olsen\t\t\t
# 10                    Joe Brody\tBryan Cranston\t\t\t
# 11               Sandra Brody\tJuliette Binoche\t\t\t
# 12      Houston Brooks\t\tCorey Hawkins\tJoe Morton\t
# 13  William Randa\t\tJohn Goodman\t\tPictured with...
# 14                 James Conrad\t\tTom Hiddleston\t\t
# 15    Hank Marlow\t\tJohn C. ReillyWill BrittainY\t\t
# 16                    Mason Weaver\t\tBrie Larson\t\t
# 17           Preston Packard\t\tSamuel L. Jackson\t\t
# 18                           San Lin\t\tJing Tian\t\t
# 19     Mark Russell\t\t\tKyle Chandler\tKyle Chandler
# 20  Madison Russell\t\t\tMillie Bobby BrownAlexand...
# 21           Emma Russell\t\t\tVera Farmiga\tPictured
# 22              Ilene and Ling Chen\t\t\tZhang Ziyi\t
# 23               Rick Stanton\t\t\tBradley Whitford\t
# 24           Sam Coleman\t\t\tThomas Middleditch[a]\t
# 25                    Alan Jonah\t\t\tCharles Dance\t
# 26                    Diane Foster\t\t\tAisha Hinds\t
# 27           Jackson Barnes\t\t\tO'Shea Jackson Jr.\t
# 28             Nathan Lind\t\t\t\tAlexander Skarsgård
# 29                  Ilene Andrews\t\t\t\tRebecca Hall
# 30                           Jia\t\t\t\tKaylee Hottle
# 31              Bernie Hayes\t\t\t\tBrian Tyree Henry
# 32              Josh Valentine\t\t\t\tJulian Dennison
# 33                Walter Simmons\t\t\t\tDemián Bichir
# 34                     Ren Serizawa\t\t\t\tShun Oguri
# 35                  Maia Simmons\t\t\t\tEiza González
# 36                    Guillermin\t\t\t\tLance Reddick
